# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamprasadg22/FDS-Experiments/blob/main/ShyamprasadG_250701711_Exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import increment_lineno
import numpy as np
array=np.random.randint(1,100,16)
array.mean()
np.percentile(array,25)
np.percentile(array,50)
np.percentile(array,75)
np.percentile(array,100)
def outdetection(array):
  sorted(array)
  q1,q3=np.percentile(array,[25,75])
  IQR=q3-1
  lr=q1-(1.5*IQR)
  ur=q3+(1.5*IQR)
  return lr,ur

lr,ur=outdetection(array)
print(lr,ur)

import seaborn as sns
# %matplotlib inline
sns.displot(array)
# Out:
# -96.25 184.75

# %%
sns.distplot(array)
# Out:
# /tmp/ipykernel_529/1133588802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(array)
# <Axes: ylabel='Density'>

# %%
new_array=array[(array>lr)&(array<ur)]
new_array
sns.displot(new_array)

# %%
lr1,ur1=outdetection(new_array)
final_array=new_array[(new_array>lr1)&(new_array<ur1)]
sns.distplot(final_array)
# Out:
# /tmp/ipykernel_529/3873068860.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_array)
# <Axes: ylabel='Density'>
