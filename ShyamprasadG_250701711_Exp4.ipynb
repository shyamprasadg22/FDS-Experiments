# %%
import numpy as np
import pandas as pd

# Read the dataset
#df = pd.read_csv("pre_process_datasample.csv",encoding="latin1",sep=None, engine="python")
df = pd.read_csv(
    "pre_process_datasample.csv", encoding="latin1", on_bad_lines="skip"
)
# Display dataset
df
# Out:
#                                                 PK
# {Ä¸&âêÁãóþM×¶5
# 1                                        \{F*Î~ÐO
# ßu
# 2   ºÅM¥Ö¼úSj¯×æ³80ëoül£Yµòâ+g
# Ñêäi/¾kEÙé...
# 3                                                @I<
# 4                                                ´ J
# 5                                       Uzk>ëÔ¶
# }
#  ÆÄ
# 6                   ÆÈF\&æ[g4<>-3)ÝÇN/
# '£hÐeØ5d}I
#  Ïs
# 8   Â0àx0{Ö
# 4íFn¥
# `H¦l
# $ñÑÛ¢àÂåÌÏ|Ã_53³...
# 9              Ùôã
# Ðï¹X&1
# ­¨ëM³
# 10              Û\toé­Ò
# Ævë0¶aCÒ7¹ÖËåx©QóÅ{Ô
# 11                                       ïÊº3ð¨Îë+
# 12  ³Bñ\tCi¬
# '¬ý?7KÁ
# ÜaT0ý©?K%á¦Úëf(kµÙÎÜ...
# 13  ï;£7
# pÙø:eß£P;Ù/L^ÒÂv¬IçðdNTïåûu}ûPK...
# 14                                                NaN
# 15  ²¬÷ÓZiæ¸D}èãçÓÙùÊ-øGiÕÞÒJ¡
# Æ<§ñù...
# 16            X:©7"ÐÒ96
# D5@0?'É
# 7BYv#d~ÃUðæäÙ
# 17                                            f«P
# 4°È
# ù2Ae
#
# 19
#  ¶C!@§i«ÂííR
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
